# %% [markdown]
# # MACHINE LEARNING
# # LINEAR REGRESSION SINGLE VARIABLE
#
# ## Predicting Per Capita Income of Canada

# %%
from sklearn import linear_model
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Samhith\OneDrive\Documents\studies\canada_per_capita_income.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')

# %%
df.rename(columns={"per capita income (US$)": "PCI"},inplace=True)

# %%
plt.scatter(df.year,df.PCI,color="red",marker="+")
plt.xlabel("year")
plt.ylabel("per capita income")
plt.plot(x,lm.predict(x))

# %%
import seaborn as sns

# %%
sns.regplot(x="year",y="PCI",data=df)
# Out:
# <Axes: xlabel='year', ylabel='PCI'>

# %%
lm=linear_model.LinearRegression()

# %%
x=df[["year"]]
y=df[["PCI"]]

# %%
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
lm.predict([[2020]])
# Out:
# C:\Users\Samhith\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[41288.69409442]])
